# %% [markdown]
# ### **Interview**

# %%
# Interview   check palindrome

# 1 Find weather the String is check palindrome

# 1.  Input: racecar
#     Output: True
# 2.  Input: MalaYa lAm
#     Output: True
# 3   Input: Sir, I demand, I am a maid named Iris
#     Output: True
# 4   Input : Red roses run no risk. Sir, on Nurse's Order. 
#     Output: True

# %%
mystr = "racecar"
revstr = mystr[::-1]

print(mystr)
print(revstr)

if mystr == revstr:
    print(True)
else:
    print(False)
# Out:
# racecar
# racecar
# True

# %%
mystr = "MalaYa lAm"
newstr = mystr.lower().replace(" ",'')
revstr = newstr[::-1]

print(mystr)
print(newstr)
print(revstr)

if newstr == revstr:
    print(True)
else:
    print(False)
# Out:
# Sir, I demand, I am a maid named Iris
# sir,idemand,iamamaidnamediris
# siridemandiamamai,dnamedi,ris
# False

# %%
mystr = "Sir, I demand, I am a maid named Iris"
newstr = mystr.lower().replace(" ",'').replace(',','')
revstr = newstr[::-1]

print(mystr)
print(newstr)
print(revstr)

if newstr == revstr:
    print(True)
else:
    print(False)
# Out:
# Sir, I demand, I am a maid named Iris
# siridemandiamamaidnamediris
# siridemandiamamaidnamediris
# True

# %%
mystr = "Red roses run no risk. Sir, on Nurse's Order. "
newstr = ''

for each in mystr:
    if each.isalpha():
        newstr += each.lower()  # newstr += each.lower()
print(newstr)

if newstr == newstr[::-1]:
    print(True)
else:
    print(False)
# Out:
# redrosesrunnorisksironnursesorder

# %%
def Check_palindrome(mystr):
    newstr = ''

    for each in mystr:
        if each.isalpha():
            newstr += each.lower()  # newstr += each.lower()
    

    if newstr == newstr[::-1]:
        return True
    else:
        return False



ans = Check_palindrome("MalaYa  lAm")
print(ans)

print(Check_palindrome("racecar"))
print(Check_palindrome("Red roses run no risk. Sir, on Nurse's Order. "))
print(Check_palindrome("Sir, I demand, I am a maid named Iris"))
# Out:
# True
# True
# True
# True
