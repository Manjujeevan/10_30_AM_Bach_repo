# %% [markdown]
# ### **Python Loop Pattern Progromming**
#
# **Print the blow pattern**
# \*\*\*\*\*
# \*\*\*\*\*
# \*\*\*\*\*
# \*\*\*\*\*
# \*\*\*\*\*

# %%
a = 1
while a<=5:   # row
    b = 1
    while b<=5:   # column
        print("*",end='')
        b += 1
    a += 1
    print()
# Out:
# *****
# *****
# *****
# *****
# *****

# %%
row = int(input("Enter a Row Number :"))
column = int(input("Enter a column Number :"))
symbol = input("Enter a symbol Number :")


a = 1
while a<=row:   # row
    b = 1
    while b<=column:   # column
        print(symbol,end='')
        b += 1
    a += 1
    print()
# Out:
# ****
# ****
# ****
# ****
# ****

# %%
row = int(input("Enter a Row Number :"))
column = int(input("Enter a column Number :"))
symbol = input("Enter a symbol Number :")

for x in range(row): 
    for y in range(column):
        print(symbol,end='')
    print()
# Out:
# @@@@@@@@
# @@@@@@@@
# @@@@@@@@
# @@@@@@@@
# @@@@@@@@
# @@@@@@@@

# %%
# Print the blow pattern (07/09/2026) 

#
##
###
####
#####

for x in range(5):
    for y in range(0,x+1):
        print("#",end='')
    print()
# Out:
# #
# ##
# ###
# ####
# #####

# %%
num  =  int(input("Enter a  number: "))  
symbol = input("Enter a  symbol: ")

for x in range(num):
    for y in range(0,x+1):
        print(symbol,end="")
    print()
# Out:
# %
# %%
# %%%
# %%%%
# %%%%%
# %%%%%%
# %%%%%%%
# %%%%%%%%

# %%
row = int(input("Enter the number of rows: "))
symbol = input("Enter the symbol: ")
for x in range(row):
    for y in range(x+1):
        print(symbol, end="")
    print()
# Out:
# #
# ##
# ###
# ####
# #####
# ######

# %%
n = int(input("Enter the number of rows: "))
symbol = input("Enter the symbol: ")

for i in range(n):
    for j in range(0,i+1):
        print(symbol, end="")
    print()
# Out:
# @
# @@
# @@@
# @@@@
# @@@@@
# @@@@@@
# @@@@@@@
# @@@@@@@@

# %%
row=int(input("enter a number for row:"))
symbol=input("enter a number for symbol:")
for x in range(row):
    for y in range(0,x+1):
        print(symbol,end="")
    print()

# %%
num = int(input("enter a number:  "))
symbol = input("enter a symbol: ")

for x in range(num):
    for y in range (x+1):
        print(symbol,end='')
    print()
# Out:
# %
# %%
# %%%
# %%%%
# %%%%%
# %%%%%%
# %%%%%%%
# %%%%%%%%
# %%%%%%%%%

# %%
for x in range(1,6):
    print("#" * x)
# Out:
# #
# ##
# ###
# ####
# #####

# %%
# Print the blow pattern  (2/9/2026)
"""
&&&&&
&&&&
&&&
&&
&
"""

num = int(input("Enter a number :"))
symbol = input("Enter a symbol :")

for i in range(num, 0, -1):
    for j in range(1, i + 1):
        print(symbol, end='')
    print()

# %%
# Print the blow pattern  (2/9/2026)

# enter a number between 0-9 :9
1
22
333
4444
55555
666666
7777777
88888888
999999999


num = int(input("Enter a number :"))
symbol = input("Enter a symbol :")

for i in range(num, 0, -1):
    for j in range(1, i + 1):
        print(symbol, end='')
    print()

# %%
# Print the blow pattern  (10/9/2026)

    #
   ##
  ###
 ####
#####
